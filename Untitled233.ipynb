# %%
import pandas as pd
import numpy as np
v=pd.read_csv("C:\\Users\\Lenovo\\Downloads\\Data Analytics\\INC+5000+Companies+2019.csv\\INC 5000 Companies 2019.csv")

# %%
v.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5012 entries, 0 to 5011
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   rank              5012 non-null   int64
#  1   profile           5012 non-null   object
#  2   name              5012 non-null   object
#  3   url               5012 non-null   object
#  4   state             5012 non-null   object
#  5   revenue           5012 non-null   object
#  6   growth_%          5012 non-null   float64
#  7   industry          5012 non-null   object
#  8   workers           5011 non-null   float64
#  9   previous_workers  5012 non-null   int64
#  10  founded           5012 non-null   int64
#  11  yrs_on_list       5012 non-null   int64
#  12  metro             4199 non-null   object
#  13  city              5012 non-null   object
# dtypes: float64(2), int64(4), object(8)
# memory usage: 548.3+ KB

# %%
v.isnull().sum()
# Out:
# rank                  0
# profile               0
# name                  0
# url                   0
# state                 0
# revenue               0
# growth_%              0
# industry              0
# workers               1
# previous_workers      0
# founded               0
# yrs_on_list           0
# metro               813
# city                  0
# dtype: int64

# %%
v.head(10)
# Out:
#    rank                                            profile  \
# 0     1               https://www.inc.com/profile/freestar
# 1     2            https://www.inc.com/profile/freightwise
# 2     3           https://www.inc.com/profile/ceces-veggie
# 3     4               https://www.inc.com/profile/ladyboss
# 4     5                 https://www.inc.com/profile/perpay
# 5     6            https://www.inc.com/profile/cano-health
# 6     7          https://www.inc.com/profile/bear-mattress
# 7     8  https://www.inc.com/profile/connected-solution...
# 8     9  https://www.inc.com/profile/providence-healthc...
# 9    10                    https://www.inc.com/profile/nom
#
#                                name                        url state  \
# 0                          Freestar        http://freestar.com    AZ
# 1                       FreightWise  http://freightwisellc.com    TN
# 2                 Cece's Veggie Co.   http://cecesveggieco.com    TX
# ...

# %%
v["metro"].fillna("No Metro",inplace=True)

# %%
v.dropna(inplace=True)

# %%
v=v.reset_index()

# %%
v.isnull().sum()
# Out:
# index               0
# rank                0
# profile             0
# name                0
# url                 0
# state               0
# revenue             0
# growth_%            0
# industry            0
# workers             0
# previous_workers    0
# founded             0
# yrs_on_list         0
# metro               0
# city                0
# dtype: int64

# %%
v.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5011 entries, 0 to 5010
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             5011 non-null   int64
#  1   rank              5011 non-null   int64
#  2   profile           5011 non-null   object
#  3   name              5011 non-null   object
#  4   url               5011 non-null   object
#  5   state             5011 non-null   object
#  6   revenue           5011 non-null   object
#  7   growth_%          5011 non-null   float64
#  8   industry          5011 non-null   object
#  9   workers           5011 non-null   float64
#  10  previous_workers  5011 non-null   int64
#  11  founded           5011 non-null   int64
#  12  yrs_on_list       5011 non-null   int64
#  13  metro             5011 non-null   object
#  14  city              5011 non-null   object
# dtypes: float64(2), int64(5), object(8)
# memory usage: 587.4+ KB

# %%
v.head()
# Out:
#    index  rank                                   profile               name  \
# 0      0     1      https://www.inc.com/profile/freestar           Freestar
# 1      1     2   https://www.inc.com/profile/freightwise        FreightWise
# 2      2     3  https://www.inc.com/profile/ceces-veggie  Cece's Veggie Co.
# 3      3     4      https://www.inc.com/profile/ladyboss           LadyBoss
# 4      4     5        https://www.inc.com/profile/perpay             Perpay
#
#                          url state       revenue    growth_%  \
# 0        http://freestar.com    AZ  36.9 Million  36680.3882
# 1  http://freightwisellc.com    TN  33.6 Million  30547.9317
# 2   http://cecesveggieco.com    TX  24.9 Million  23880.4852
# 3        http://ladyboss.com    NM  32.4 Million  21849.8925
# 4          http://perpay.com    PA  22.5 Million  18166.4070
#
#                        industry  workers  previous_workers  founded  \
# 0       Advertising & Marketing     40.0                 5     2015
# ...

# %%
for i in range(len(v["name"])):
    k=v["revenue"][i]
    if "Milloin" in str(k):
        k=k.replace(" Million","")
        v.loc[i,"revenue"]=float(k)*1000000
    if "Billion" in str(k):
        k=k.replace(" Billion","")
        v.loc[i,"revenue"]=float(k)*1000000000

# %%
v.head()
# Out:
#    index  rank                                   profile               name  \
# 0      0     1      https://www.inc.com/profile/freestar           Freestar
# 1      1     2   https://www.inc.com/profile/freightwise        FreightWise
# 2      2     3  https://www.inc.com/profile/ceces-veggie  Cece's Veggie Co.
# 3      3     4      https://www.inc.com/profile/ladyboss           LadyBoss
# 4      4     5        https://www.inc.com/profile/perpay             Perpay
#
#                          url state     revenue    growth_%  \
# 0        http://freestar.com    AZ  36900000.0  36680.3882
# 1  http://freightwisellc.com    TN  33600000.0  30547.9317
# 2   http://cecesveggieco.com    TX  24900000.0  23880.4852
# 3        http://ladyboss.com    NM  32400000.0  21849.8925
# 4          http://perpay.com    PA  22500000.0  18166.4070
#
#                        industry  workers  previous_workers  founded  \
# 0       Advertising & Marketing     40.0                 5     2015
# ...

# %%
v.to_csv("INC_Comapnies.csv")
